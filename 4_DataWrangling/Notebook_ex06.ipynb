# %%
import numpy as np
import pandas as pd

business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

#generate tickers
tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

#create indexs
index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

# create DFs
market_data = pd.DataFrame(index=index,data=np.random.randn(len(index), 1),columns=['Prediction'])

# %%
# Unstack the DataFrame
unstacked_market_data = market_data.unstack(level='Ticker')

print("Question 1")
print(unstacked_market_data.head(3))
# Out:
# Question 1
#            Prediction
# Ticker           AAPL      AMZN       DAI        FB        GE
# Date
# 2021-01-01  -0.345316  0.454206  0.011615 -0.820500  0.439477
# 2021-01-04  -0.531695  2.026328  0.117373 -1.462633  0.652293
# 2021-01-05  -0.897655 -1.353196  1.156862 -0.105977  0.226380

# %%
import matplotlib.pyplot as plt

# Plot the time series
unstacked_market_data.plot(title="Stoks 2023", figsize=(12, 8))
plt.xlabel("Date")
plt.ylabel("Prediction")
plt.legend(loc='best')
# Out:
# /Users/sai/Prog/piscine-ai/4_DataWrangling/lib/python3.10/site-packages/matplotlib/axis.py:1769: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   ret = self.converter.convert(x, self.units, self)
# /Users/sai/Prog/piscine-ai/4_DataWrangling/lib/python3.10/site-packages/matplotlib/axis.py:1769: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ret = self.converter.convert(x, self.units, self)
# /Users/sai/Prog/piscine-ai/4_DataWrangling/lib/python3.10/site-packages/matplotlib/axis.py:1769: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ret = self.converter.convert(x, self.units, self)
# /Users/sai/Prog/piscine-ai/4_DataWrangling/lib/python3.10/site-packages/matplotlib/axis.py:1769: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ret = self.converter.convert(x, self.units, self)
# /Users/sai/Prog/piscine-ai/4_DataWrangling/lib/python3.10/site-packages/matplotlib/axis.py:1769: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ret = self.converter.convert(x, self.units, self)
# /Users/sai/Prog/piscine-ai/4_DataWrangling/lib/python3.10/site-packages/matplotlib/axis.py:1769: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ret = self.converter.convert(x, self.units, self)
# /Users/sai/Prog/piscine-ai/4_DataWrangling/lib/python3.10/site-packages/matplotlib/axis.py:1495: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return self.major.locator()
# /Users/sai/Prog/piscine-ai/4_DataWrangling/lib/python3.10/site-packages/matplotlib/axis.py:1495: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   return self.major.locator()
# /Users/sai/Prog/piscine-ai/4_DataWrangling/lib/python3.10/site-packages/matplotlib/ticker.py:216: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return [self(value, i) for i, value in enumerate(values)]

# %%
print("Question 2")
# Show the plot
plt.show()
# Out:
# Question 2
